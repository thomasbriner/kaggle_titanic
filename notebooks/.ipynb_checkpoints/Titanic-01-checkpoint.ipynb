# %%
import pandas as pd

# %%
data = pd.read_csv('../input/train.csv')
data

X = data
X
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
remove_columns = ['PassengerId', 'Survived', 'Name', 'Ticket', 'Cabin']

categorical_columns = ['Sex', 'Embarked']

to_be_scaled_columns = ['Fare']


# X = data.drop(['Survived'], axis = 1)
# X = X.drop(alphanumeric_columns, axis = 1)

print(X['Embarked'].unique())

y = data['Survived']

from sklearn import preprocessing


#X.apply(le.fit_transform)

X.shape

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

X['Embarked'].fillna('U', inplace=True)

print(X['Embarked'].unique())

labelencoder_X = LabelEncoder()
X['Embarked'] = labelencoder_X.fit_transform(X['Embarked'])

X

# %%
onehotencoder = OneHotEncoder()
Z = onehotencoder.fit_transform(X['Embarked'].values.reshape(-1,1))

Z.toarray()[:,0:-1]

# %%
onehotencoder.fit_transform(X['Pclass'].values.reshape(-1,1)).toarray()
#X['Pclass']

# %%
labelencoder_X.fit_transform(X['Sex'])

# %%
X = X.drop(remove_columns, axis = 1)

from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values = 'NaN', strategy = 'mean', axis = 0)
imputer = imputer.fit(X)

X

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values = 'NaN', strategy = 'mean', axis = 0)
imputer = imputer.fit(X[:, 1:3])
X[:, 1:3] = imputer.transform(X[:, 1:3])

# Encoding categorical data
# Encoding the Independent Variable
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X = LabelEncoder()
X[:, 0] = labelencoder_X.fit_transform(X[:, 0])
onehotencoder = OneHotEncoder(categorical_features = [0])
X = onehotencoder.fit_transform(X).toarray()
# Encoding the Dependent Variable
labelencoder_y = LabelEncoder()
y = labelencoder_y.fit_transform(y)

# %%
X.loc[X['Sex'] == 'male'].groupby('Survived').agg('count')['Sex']

# %%
X.loc[(X['Sex'] == 'male') & (X['Survived'] == True)]

# %%
import matplotlib.pyplot as plt
import numpy as np


X['Embarked'].fillna('U', inplace=True)
columns = ['Sex', 'Embarked', 'Pclass', 'SibSp', 'Parch']

plt.figure(figsize=(15,20))


for idx, column in enumerate(columns):
    values = X[column].unique()
    values.sort(axis=0)
        
    ind = np.arange(len(values))


    survived = X.loc[X['Survived'] == True].groupby(column).agg('count')['Survived']
    not_survived = X.loc[X['Survived'] == False].groupby(column).agg('count')['Survived']

    for value in values:
        if (value not in survived.index.unique()):
            survived[value] = 0
        if (value not in not_survived.index.unique()):
            not_survived[value] = 0
               
    plt.subplot(round(len(columns)/2)+1,2,idx+1)  
                
    plt.bar(ind, survived)
    plt.bar(ind, not_survived, color='r', bottom=survived)
    plt.xticks(ind,values)
    plt.legend(('survived', 'not survived'))
plt.show()

# %% [raw]
# import matplotlib.pyplot as plt
# import numpy as np
#
#
# X['Embarked'].fillna('U', inplace=True)
# columns = ['Sex', 'Embarked', 'Pclass', 'SibSp', 'Parch']
#
# for column in columns:
#     values = X[column].unique()
#     values.sort(axis=0)
#
#     ind = np.arange(len(values))
#
#
#     survived = X.loc[X['Survived'] == True].groupby(column).agg('count')['Survived']
#     not_survived = X.loc[X['Survived'] == False].groupby(column).agg('count')['Survived']
#
#     for value in values:
#         if (value not in survived.index.unique()):
#             survived[value] = 0
#         if (value not in not_survived.index.unique()):
#             not_survived[value] = 0
#
#     plt.bar(ind, survived)
#     plt.bar(ind, not_survived, color='r', bottom=survived)
#     plt.xticks(ind,values)
#     plt.legend(('survived', 'not survived'))
#     plt.show()

# %%
male = X.loc[X['Survived'] == 'male'].groupby('Survived').agg('count')['Sex']
female = X.loc[X['Sex'] == 'female'].groupby('Survived').agg('count')['Sex']

ind = np.arange(2)
p1 = plt.bar(ind, male, color='r')
p1 = plt.bar(ind, female, color='b', bottom=male)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.subplot(3,2,1)
plt.boxplot(X['Age'].dropna())

plt.subplot(3,2,2)
plt.hist(X['Pclass'].fillna(10), bins='auto')

plt.subplot(3,2,3)
X['Embarked'].fillna('U').value_counts().plot(kind='bar')
#plt.hist(X['Embarked'].fillna('U'), bins=['C', 'S', 'Q'])



plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
X = [[0, 0], [1, 1]]
Y = [0, 1]
clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X, Y)

# %%
clf.feature_importances_
